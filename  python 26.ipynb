# %%
import pandas as pd
import numpy as np
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
ipl = pd.DataFrame(ipl_data)

print (ipl)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
c=ipl.groupby('Team').groups
c
# Out:
# {'Devils': Int64Index([2, 3], dtype='int64'),
#  'Kings': Int64Index([4, 6, 7], dtype='int64'),
#  'Riders': Int64Index([0, 1, 8, 11], dtype='int64'),
#  'Royals': Int64Index([9, 10], dtype='int64'),
#  'kings': Int64Index([5], dtype='int64')}

# %%
c=ipl.groupby(['Team','Year']).groups
c
# Out:
# {('Devils', 2014): Int64Index([2], dtype='int64'),
#  ('Devils', 2015): Int64Index([3], dtype='int64'),
#  ('Kings', 2014): Int64Index([4], dtype='int64'),
#  ('Kings', 2016): Int64Index([6], dtype='int64'),
#  ('Kings', 2017): Int64Index([7], dtype='int64'),
#  ('Riders', 2014): Int64Index([0], dtype='int64'),
#  ('Riders', 2015): Int64Index([1], dtype='int64'),
#  ('Riders', 2016): Int64Index([8], dtype='int64'),
#  ('Riders', 2017): Int64Index([11], dtype='int64'),
#  ('Royals', 2014): Int64Index([9], dtype='int64'),
#  ('Royals', 2015): Int64Index([10], dtype='int64'),
#  ('kings', 2015): Int64Index([5], dtype='int64')}

# %%
grouped=ipl.groupby('Year')
print(grouped.get_group(2014))
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701

# %%
#datetime.now()gives you the current data and time
print(pd.datetime.now())
# Out:
# 2019-05-26 12:50:40.422709

# %%
Reading files
Following files can be read in pandas:
df.to_csv(...) # csv file
df.to_hdf(...) # HDF5 file
df.to_pickle(...) # serialized object
df.to_sql(...) # to SQL database
df.to_excel(...) # to Excel sheet
df.to_json(...) # to JSON string
df.to_html(...) # render as HTML table
df.to_feather(...) # binary feather-format
df.to_latex(...) # tabular environment table
df.to_stata(...) # Stata binary data files
df.to_msgpack(...) # msgpack (serialize) object
df.to_gbq(...) # to a Google BigQuery table.
df.to_string(...) # console-friendly tabular output.
df.to_clipboard(...) # clipboard that can be pasted into Excel

# %%
#pd.read_filetype('path')

# %%
d=pd.read_csv("https://raw.githubusercontent.com/suyashi29/python-su/master/data/Car_sales.csv")
d
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura        Integra              16.919               16.360
# 1          Acura             TL              39.384               19.875
# 2          Acura             CL              14.114               18.225
# 3          Acura             RL               8.588               29.725
# 4           Audi             A4              20.397               22.255
# 5           Audi             A6              18.780               23.555
# 6           Audi             A8               1.380               39.000
# 7            BMW           323i              19.747                  NaN
# 8            BMW           328i               9.231               28.675
# 9            BMW           528i              17.527               36.125
# 10         Buick        Century              91.561               12.475
# 11         Buick          Regal              39.350               13.740
# ...

# %%
d.tail(2)
this ll fetch data from bottom
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 155        3.601           18.5             23.0     4/26/2011
# 156        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 155         101.623357
# 156          85.735655

# %%
d.tail(5)
fetch data from top
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 152                24.4          1.9       160.0      100.5   67.6   176.6
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
# ...

# %%
#applying filter function
d.filter(["Manufacturer","Model"])
# Out:
#     Manufacturer          Model
# 0          Acura        Integra
# 1          Acura             TL
# 2          Acura             CL
# 3          Acura             RL
# 4           Audi             A4
# 5           Audi             A6
# 6           Audi             A8
# 7            BMW           323i
# 8            BMW           328i
# 9            BMW           528i
# 10         Buick        Century
# 11         Buick          Regal
# 12         Buick    Park Avenue
# 13         Buick        LeSabre
# 14      Cadillac        DeVille
# 15      Cadillac        Seville
# 16      Cadillac       Eldorado
# 17      Cadillac         Catera
# 18      Cadillac       Escalade
# 19     Chevrolet       Cavalier
# 20     Chevrolet         Malibu
# 21     Chevrolet         Lumina
# 22     Chevrolet    Monte Carlo
# 23     Chevrolet         Camaro
# 24     Chevrolet       Corvette
# 25     Chevrolet          Prizm
# 26     Chevrolet          Metro
# 27     Chevrolet         Impala
# ...

# %%
#loc fetch rows and columns of particukar data
d.loc[:,'Model']
# Out:
# 0            Integra
# 1                 TL
# 2                 CL
# 3                 RL
# 4                 A4
# 5                 A6
# 6                 A8
# 7               323i
# 8               328i
# 9               528i
# 10           Century
# 11             Regal
# 12       Park Avenue
# 13           LeSabre
# 14           DeVille
# 15           Seville
# 16          Eldorado
# 17            Catera
# 18          Escalade
# 19          Cavalier
# 20            Malibu
# 21            Lumina
# 22       Monte Carlo
# 23            Camaro
# 24          Corvette
# 25             Prizm
# 26             Metro
# 27            Impala
# 28     Sebring Coupe
# 29     Sebring Conv.
#            ...
# 127            5-Sep
# 128            3-Sep
# 129               SL
# 130               SC
# 131               SW
# 132               LW
# 133               LS
# 134          Outback
# 135         Forester
# 136          Corolla
# 137            Camry
# 138           Avalon
# ...

# %%
##read excel file 
f=pd.read_csv("D:\")
# Out:
#   File "<ipython-input-45-d4d4b00ad475>", line 2
#     f=pd.read_csv("D:\")
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
conda install -c conda-forge pandas-profiling
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
d=pd.read_csv(r"https://raw.githubusercontent.com/suyashi29/python-su/master/data/Car_sales.csv")

# %%
import pandas_profiling
profile=pandas_profiling.ProfileReport(d)
profile.to_file(outputfile='sales_before_preprocessing.html')

# %%
combining two seprate data
#creating a csv file
# Out:
#   File "<ipython-input-23-f4dca52d73cb>", line 1
#     combining two seprate data
#                 ^
# SyntaxError: invalid syntax

# %%
empide=[100,200,300,400]

# %%
emproles=["lead","trainer","consultant","sales"]
